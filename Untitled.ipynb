# %%
import pandas as pd

# %%
data = pd.read_csv("realtor-data.csv")

# %%
data.head()
# Out:
#    brokered_by    status     price  bed  bath  acre_lot     street  \
# 0     103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1      52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2     103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3      31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4      34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
#
#          city        state  zip_code  house_size prev_sold_date
# 0    Adjuntas  Puerto Rico     601.0       920.0            NaN
# 1    Adjuntas  Puerto Rico     601.0      1527.0            NaN
# 2  Juana Diaz  Puerto Rico     795.0       748.0            NaN
# 3       Ponce  Puerto Rico     731.0      1800.0            NaN
# 4    Mayaguez  Puerto Rico     680.0         NaN            NaN

# %%
data.tail()
# Out:
#          brokered_by status     price  bed  bath  acre_lot     street  \
# 2226377      23009.0   sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0   sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0   sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0   sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0   sold  580000.0  5.0   3.0      0.31   307704.0
#
#              city       state  zip_code  house_size prev_sold_date
# 2226377  Richland  Washington   99354.0      3600.0     2022-03-25
# 2226378  Richland  Washington   99354.0      1616.0     2022-03-25
# 2226379  Richland  Washington   99354.0      3200.0     2022-03-24
# 2226380  Richland  Washington   99354.0       933.0     2022-03-24
# 2226381  Richland  Washington   99354.0      3615.0     2022-03-23

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          object
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            object
#  8   state           object
#  9   zip_code        float64
#  10  house_size      float64
#  11  prev_sold_date  object
# dtypes: float64(8), object(4)
# memory usage: 203.8+ MB

# %%
data.describe()
# Out:
#         brokered_by         price           bed          bath      acre_lot  \
# count  2.221849e+06  2.224841e+06  1.745065e+06  1.714611e+06  1.900793e+06
# mean   5.293989e+04  5.241955e+05  3.275841e+00  2.496440e+00  1.522303e+01
# std    3.064275e+04  2.138893e+06  1.567274e+00  1.652573e+00  7.628238e+02
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.386100e+04  1.650000e+05  3.000000e+00  2.000000e+00  1.500000e-01
# 50%    5.288400e+04  3.250000e+05  3.000000e+00  2.000000e+00  2.600000e-01
# 75%    7.918300e+04  5.500000e+05  4.000000e+00  3.000000e+00  9.800000e-01
# max    1.101420e+05  2.147484e+09  4.730000e+02  8.300000e+02  1.000000e+05
#
#              street      zip_code    house_size
# count  2.215516e+06  2.226083e+06  1.657898e+06
# mean   1.012325e+06  5.218668e+04  2.714471e+03
# std    5.837635e+05  2.895408e+04  8.081635e+05
# min    0.000000e+00  0.000000e+00  4.000000e+00
# 25%    5.063128e+05  2.961700e+04  1.300000e+03
# 50%    1.012766e+06  4.838200e+04  1.760000e+03
# 75%    1.521173e+06  7.807000e+04  2.413000e+03
# max    2.001357e+06  9.999900e+04  1.040400e+09

# %%
data.head()
# Out:
#    brokered_by    status     price  bed  bath  acre_lot     street  \
# 0     103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1      52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2     103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3      31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4      34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
#
#          city        state  zip_code  house_size prev_sold_date
# 0    Adjuntas  Puerto Rico     601.0       920.0            NaN
# 1    Adjuntas  Puerto Rico     601.0      1527.0            NaN
# 2  Juana Diaz  Puerto Rico     795.0       748.0            NaN
# 3       Ponce  Puerto Rico     731.0      1800.0            NaN
# 4    Mayaguez  Puerto Rico     680.0         NaN            NaN

# %%
data.isna().sum()
# Out:
# brokered_by         4533
# status                 0
# price               1541
# bed               481317
# bath              511771
# acre_lot          325589
# street             10866
# city                1407
# state                  8
# zip_code             299
# house_size        568484
# prev_sold_date    734297
# dtype: int64

# %%
data = data.drop(columns = ["brokered_by","zip_code","prev_sold_date"])

# %%
data
# Out:
#            status      price  bed  bath  acre_lot     street          city  \
# 502      for_sale   110000.0  7.0   3.0      0.09  1842706.0        Dorado
# 2270     for_sale   950000.0  5.0   4.0      0.99  1260473.0  Saint Thomas
# 2277     for_sale  6899000.0  4.0   6.0      0.83    17467.0  Saint Thomas
# 3409     for_sale   525000.0  3.0   3.0      0.45  1813270.0        Agawam
# 3410     for_sale   289900.0  3.0   2.0      0.36  1698080.0        Agawam
# ...           ...        ...  ...   ...       ...        ...           ...
# 2226377      sold   359900.0  4.0   2.0      0.33   353094.0      Richland
# 2226378      sold   350000.0  3.0   2.0      0.10  1062149.0      Richland
# 2226379      sold   440000.0  6.0   3.0      0.50   405677.0      Richland
# 2226380      sold   179900.0  2.0   1.0      0.09   761379.0      Richland
# 2226381      sold   580000.0  5.0   3.0      0.31   307704.0      Richland
#
#                   state  house_size
# 502         Puerto Rico      1192.0
# 2270     Virgin Islands      5000.0
# 2277     Virgin Islands      4600.0
# 3409      Massachusetts      2314.0
# 3410      Massachusetts      1276.0
# ...                 ...         ...
# 2226377      Washington      3600.0
# 2226378      Washington      1616.0
# 2226379      Washington      3200.0
# 2226380      Washington       933.0
# 2226381      Washington      3615.0
#
# [1084909 rows x 9 columns]

# %%
data.isna().sum().sum()
# Out:
# np.int64(0)

# %%
data.dropna(inplace=True)

# %%
data.isna().sum().sum()
# Out:
# np.int64(0)

# %%
data.duplicated().sum()
# Out:
# np.int64(190)

# %%
data.drop_duplicates(inplace = True)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.head()
# Out:
#         status      price  bed  bath  acre_lot     street          city  \
# 502   for_sale   110000.0  7.0   3.0      0.09  1842706.0        Dorado
# 2270  for_sale   950000.0  5.0   4.0      0.99  1260473.0  Saint Thomas
# 2277  for_sale  6899000.0  4.0   6.0      0.83    17467.0  Saint Thomas
# 3409  for_sale   525000.0  3.0   3.0      0.45  1813270.0        Agawam
# 3410  for_sale   289900.0  3.0   2.0      0.36  1698080.0        Agawam
#
#                state  house_size
# 502      Puerto Rico      1192.0
# 2270  Virgin Islands      5000.0
# 2277  Virgin Islands      4600.0
# 3409   Massachusetts      2314.0
# 3410   Massachusetts      1276.0

# %%
data.shape
# Out:
# (1084719, 9)

# %%
data["status"].value_counts()
# Out:
# status
# sold        606849
# for_sale    477870
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data["state"].value_counts().sort_values(ascending=False).head(10).plot(kind="bar")
plt.title("Number of House by State")
plt.ylabel("Listing Number")
plt.xlabel("State")
plt.show()

# %%
data
# Out:
#            status      price  bed  bath  acre_lot     street          city  \
# 502      for_sale   110000.0  7.0   3.0      0.09  1842706.0        Dorado
# 2270     for_sale   950000.0  5.0   4.0      0.99  1260473.0  Saint Thomas
# 2277     for_sale  6899000.0  4.0   6.0      0.83    17467.0  Saint Thomas
# 3409     for_sale   525000.0  3.0   3.0      0.45  1813270.0        Agawam
# 3410     for_sale   289900.0  3.0   2.0      0.36  1698080.0        Agawam
# ...           ...        ...  ...   ...       ...        ...           ...
# 2226377      sold   359900.0  4.0   2.0      0.33   353094.0      Richland
# 2226378      sold   350000.0  3.0   2.0      0.10  1062149.0      Richland
# 2226379      sold   440000.0  6.0   3.0      0.50   405677.0      Richland
# 2226380      sold   179900.0  2.0   1.0      0.09   761379.0      Richland
# 2226381      sold   580000.0  5.0   3.0      0.31   307704.0      Richland
#
#                   state  house_size
# 502         Puerto Rico      1192.0
# 2270     Virgin Islands      5000.0
# 2277     Virgin Islands      4600.0
# 3409      Massachusetts      2314.0
# 3410      Massachusetts      1276.0
# ...                 ...         ...
# 2226377      Washington      3600.0
# 2226378      Washington      1616.0
# 2226379      Washington      3200.0
# 2226380      Washington       933.0
# 2226381      Washington      3615.0
#
# [1084719 rows x 9 columns]

# %%
data.groupby("state")["price"].mean().sort_values(ascending = False).astype(int)
# Out:
# state
# Hawaii                  1457250
# Virgin Islands          1291675
# District of Columbia    1188105
# California              1079511
# Utah                     862922
# Colorado                 808673
# Connecticut              792866
# Nevada                   734785
# Washington               717087
# Massachusetts            702837
# Montana                  683083
# Florida                  641800
# Oregon                   622010
# New Hampshire            609501
# Idaho                    599801
# New York                 590198
# Puerto Rico              573611
# Wyoming                  556509
# Virginia                 547960
# Arizona                  542458
# New Jersey               520160
# South Carolina           506937
# Maryland                 495790
# Alaska                   494244
# Maine                    490554
# Rhode Island             468721
# Vermont                  467501
# Tennessee                451230
# Texas                    434812
# North Carolina           426308
# Georgia                  403115
# Delaware                 396970
# Minnesota                383304
# South Dakota             379066
# New Mexico               374914
# Illinois                 356027
# Arkansas                 335926
# Pennsylvania             330871
# Wisconsin                320536
# Nebraska                 314423
# Louisiana                312431
# Alabama                  309689
# Indiana                  307926
# North Dakota             307683
# Michigan                 288309
# Missouri                 281842
# Kentucky                 277488
# Oklahoma                 271782
# Kansas                   264554
# Mississippi              255708
# West Virginia            252806
# Iowa                     245545
# Ohio                     226957
# Name: price, dtype: int64

# %%
data.groupby("city")["price"].mean().sort_values(ascending = False).astype(int)
# Out:
# city
# Bal Harbour        26585714
# Carpinteria        25453769
# Gulf Stream        21461250
# Palm Beach         18787650
# Montecito          17982187
#                      ...
# Melbeta               12000
# Center Junction        8500
# Red House              7500
# Rowan                  7500
# Pilot Mound            6500
# Name: price, Length: 15103, dtype: int64

# %%
data.groupby(["state","city"])["price"].mean().reset_index()
# Out:
#          state         city         price
# 0      Alabama    Abbeville  2.057182e+05
# 1      Alabama   Adamsville  1.459324e+05
# 2      Alabama        Adger  1.531333e+05
# 3      Alabama        Akron  4.499333e+05
# 4      Alabama    Alabaster  2.644765e+05
# ...        ...          ...           ...
# 22665  Wyoming  Thermopolis  4.046750e+05
# 22666  Wyoming   Torrington  2.269800e+05
# 22667  Wyoming    Wheatland  2.440833e+05
# 22668  Wyoming       Wilson  4.200000e+06
# 22669  Wyoming      Worland  2.075000e+05
#
# [22670 rows x 3 columns]

# %%
data.select_dtypes(include=["number"]).corr()["price"]
# Out:
# price         1.000000
# bed           0.205037
# bath          0.373086
# acre_lot      0.000813
# street        0.002608
# house_size    0.187690
# Name: price, dtype: float64

# %%
data
# Out:
#            status      price  bed  bath  acre_lot     street          city  \
# 502      for_sale   110000.0  7.0   3.0      0.09  1842706.0        Dorado
# 2270     for_sale   950000.0  5.0   4.0      0.99  1260473.0  Saint Thomas
# 2277     for_sale  6899000.0  4.0   6.0      0.83    17467.0  Saint Thomas
# 3409     for_sale   525000.0  3.0   3.0      0.45  1813270.0        Agawam
# 3410     for_sale   289900.0  3.0   2.0      0.36  1698080.0        Agawam
# ...           ...        ...  ...   ...       ...        ...           ...
# 2226377      sold   359900.0  4.0   2.0      0.33   353094.0      Richland
# 2226378      sold   350000.0  3.0   2.0      0.10  1062149.0      Richland
# 2226379      sold   440000.0  6.0   3.0      0.50   405677.0      Richland
# 2226380      sold   179900.0  2.0   1.0      0.09   761379.0      Richland
# 2226381      sold   580000.0  5.0   3.0      0.31   307704.0      Richland
#
#                   state  house_size
# 502         Puerto Rico      1192.0
# 2270     Virgin Islands      5000.0
# 2277     Virgin Islands      4600.0
# 3409      Massachusetts      2314.0
# 3410      Massachusetts      1276.0
# ...                 ...         ...
# 2226377      Washington      3600.0
# 2226378      Washington      1616.0
# 2226379      Washington      3200.0
# 2226380      Washington       933.0
# 2226381      Washington      3615.0
#
# [1084719 rows x 9 columns]

# %%
X = data[["bed","bath","house_size"]]

# %%
y = data["price"]

# %%
X
# Out:
#          bed  bath  house_size
# 502      7.0   3.0      1192.0
# 2270     5.0   4.0      5000.0
# 2277     4.0   6.0      4600.0
# 3409     3.0   3.0      2314.0
# 3410     3.0   2.0      1276.0
# ...      ...   ...         ...
# 2226377  4.0   2.0      3600.0
# 2226378  3.0   2.0      1616.0
# 2226379  6.0   3.0      3200.0
# 2226380  2.0   1.0       933.0
# 2226381  5.0   3.0      3615.0
#
# [1084719 rows x 3 columns]

# %%
X.columns
# Out:
# Index(['bed', 'bath', 'house_size'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train
# Out:
#          bed  bath  house_size
# 2204207  3.0   1.0      1196.0
# 1827895  4.0   2.0      2145.0
# 2000360  4.0   3.0      2382.0
# 1535234  2.0   2.0      1494.0
# 1464118  3.0   2.0       945.0
# ...      ...   ...         ...
# 1709330  3.0   2.0      1458.0
# 300998   2.0   1.0       855.0
# 1460214  4.0   3.0      1936.0
# 1656958  3.0   3.0      1709.0
# 1204372  3.0   2.0      1248.0
#
# [867775 rows x 3 columns]

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.26120806, -1.16387819, -0.32207766],
#        [ 0.45700155, -0.39772683,  0.02597727],
#        [ 0.45700155,  0.36842454,  0.11289931],
#        ...,
#        [ 0.45700155,  0.36842454, -0.0506755 ],
#        [-0.26120806,  0.36842454, -0.13392995],
#        [-0.26120806, -0.39772683, -0.30300616]], shape=(867775, 3))

# %%
import joblib
joblib.dump(scaler, "Scaler.pkl")
# Out:
# ['Scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 345957.4978320901

# %%
joblib.dump(lr, "model.pkl")
# Out:
# ['model.pkl']
